# %% [markdown]
# # plotly

# %%
import plotly.graph_objects as go
import numpy as np

r = np.random.normal(0, 25, 10000)

go.Figure(
    data=[go.Histogram(x=r)], layout_title_text="Hello World!"
).show()
